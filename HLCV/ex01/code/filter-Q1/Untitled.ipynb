# %%
from skimage.io import imread
import skimage
import matplotlib.pyplot as plt

# %%
img = imread("/home/maria/Pictures/lena.jpg")

# %%
plt.imshow(img,"gray")

# %%
plt.imshow(img+255,"gray")

# %%
img
# Out:
# array([[143, 144, 145, ..., 148, 138, 112],
#        [143, 144, 145, ..., 151, 140, 110],
#        [144, 145, 145, ..., 150, 138, 106],
#        ...,
#        [ 25,  29,  32, ...,  86,  86,  84],
#        [ 24,  29,  34, ...,  85,  87,  90],
#        [ 23,  29,  35, ...,  82,  83,  90]], dtype=uint8)

# %%
255-143
# Out:
# 112
